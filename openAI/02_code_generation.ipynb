# %% [markdown]
# #### Code generation
# - 코딩에 최적화 된 모델 (Codex) 사용
# - 코딩에 특화된 LLM
# - gpt-5.1-codex-max

# %%
from dotenv import load_dotenv, find_dotenv
# .env 파일 정보 가져오기
load_dotenv(find_dotenv())
# Out:
# True

# %%
from openai import OpenAI
client = OpenAI()
prompt = """
- FastAPI 로 /health 엔드포인트를 만들고 get /health 요청에 {"state":"OK"} JSON 을 반환하는 예제를 작성해라
- 실행방법을 설명해라
"""
response = client.responses.create(
    model="gpt-5.1-codex-max",
    reasoning={"effort":"medium"},
    input=prompt
)

print(response.output_text)
# Out:
# 아래는 FastAPI로 `/health` 엔드포인트를 만들어, GET 요청 시 `{"state":"OK"}` 형태의 JSON을 반환하는 간단한 예제와 실행 방법입니다.
#
# ## 예제 코드 (main.py)
# ```python
# from fastapi import FastAPI
#
# app = FastAPI()
#
# @app.get("/health")
# def read_health():
#     return {"state": "OK"}
# ```
#
# ## 실행 방법
# 1. **FastAPI 및 Uvicorn 설치**
#    ```bash
#    pip install fastapi uvicorn
#    ```
#
# 2. **서버 실행**
#    현재 디렉터리에 `main.py` 파일을 만든 뒤 다음 명령을 실행합니다.
#    ```bash
#    uvicorn main:app --reload
#    ```
#    (포트나 호스트를 지정하고 싶다면 `--host 0.0.0.0 --port 8000` 등 옵션을 사용할 수 있습니다.)
#
# 3. **동작 확인**
#    브라우저나 HTTP 클라이언트로 다음 URL에 접속합니다.
#    ```
#    http://127.0.0.1:8000/health
#    ```
#    `{"state":"OK"}` 응답을 확인할 수 있습니다.

# %%
from openai import OpenAI
client = OpenAI()
prompt = """
- FastAPI 로 /health 엔드포인트를 만들고 get /health 요청에 {"state":"OK"} JSON 을 반환하는 예제를 작성해라
- 실행방법을 설명해라
"""
response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort":"medium"},
    input=prompt
)

print(response.output_text)
# Out:
# 아래는 FastAPI로 GET /health 엔드포인트를 만들고 {"state":"OK"}를 반환하는 최소 예제와 실행 방법입니다.
#
# 1) 예제 코드 (파일명: main.py)
# ```python
# from fastapi import FastAPI
#
# app = FastAPI()
#
# @app.get("/health")
# def health():
#     return {"state": "OK"}
# ```
#
# 2) 실행 전 준비
# - Python 3.7+ 필요
# - 가상환경(선택 사항)을 만들고 활성화한 뒤 필요한 패키지 설치:
#
# Unix/macOS:
# ```bash
# python3 -m venv .venv
# source .venv/bin/activate
# pip install --upgrade pip
# pip install fastapi uvicorn
# ```
#
# Windows (PowerShell):
# ```powershell
# python -m venv .venv
# .\.venv\Scripts\Activate.ps1
# python -m pip install --upgrade pip
# pip install fastapi uvicorn
# ```
#
# 3) 서버 실행
# 터미널에서 프로젝트 폴더(예: main.py가 있는 위치)로 이동한 뒤:
# ```bash
# uvicorn main:app --reload --host 0.0.0.0 --port 8000
# ```
# - --reload: 코드 수정 시 자동 재시작 (개발용)
# - host/port는 필요에 따라 변경 가능
#
# 4) 확인(요청 보내기)
# 브라우저에서 http://127.0.0.1:8000/health 접속 또는 curl 사용:
# ```bash
# curl http://127.0.0.1:8000/health
# # 출력: {"state":"OK"}
# ```
#
# 5) 참고
# ...

# %%
from openai import OpenAI
client = OpenAI()
code="""
import Random 
a = random.randint(1,12)
b = random.randint(1,12)
for i in range(10): 
question = "What is "+a+" x "+b+"? "
answer = input(question) 
if answer = a*b 
print (Well done!) 
else: print("No.")

"""
prompt = f"""
- python 코드가 제공되면, 해당 코드에서 버그를 찾아 수정하는 것이 당신의 역할입니다.
- 원본코드:{code}
"""
response = client.responses.create(
    model="gpt-5-mini",
    reasoning={"effort":"medium"},
    input=prompt
)

print(response.output_text)
# Out:
# 수정한 코드와 변경 이유는 아래와 같습니다. (질문을 매 반복마다 새로 만들도록 수정했습니다.)
#
# 수정된 코드:
# ```python
# import random
#
# for i in range(10):
#     a = random.randint(1, 12)
#     b = random.randint(1, 12)
#     try:
#         answer = int(input(f"What is {a} x {b}? "))
#     except ValueError:
#         print("Please enter a valid integer.")
#         continue
#
#     if answer == a * b:
#         print("Well done!")
#     else:
#         print("No. The correct answer is", a * b)
# ```
#
# 주요 변경 및 이유:
# - import Random → import random: 모듈 이름은 소문자 random입니다.
# - random.randint 호출 위치: 반복마다 다른 문제를 내려면 for 내부에서 a, b를 생성합니다(원하면 반복 밖으로 빼서 같은 문제를 10번 물을 수도 있음).
# - 문자열 연결 문제: 정수와 문자열을 바로 더할 수 없으므로 f-string(f"...")를 사용했습니다.
# - input 반환값은 문자열이므로 int()로 변환하여 숫자 비교가 가능하도록 했습니다. (잘못된 입력을 대비해 try/except로 처리)
# - if answer = a*b → if answer == a * b: 비교 연산자는 == 입니다.
# - print (Well done!) → print("Well done!"): 문자열은 따옴표로 감싸야 합니다.
#
# 원하면 문제 생성 방식(같은 문제 반복 vs 매번 새 문제)이나 출력 문구를 바꾸는 버전도 만들어 드리겠습니다.

# %%
from openai import OpenAI
client = OpenAI()
prompt = """
- 당신은 문장을 받아서 표준 한국어로 변환하는 역할을 수행합니다.
"""
response = client.responses.create(
    model="gpt-5-mini",
    instructions=prompt,
    input="안갔어 시장에 그녀는"
)

print(response.output_text)
# Out:
# 그녀는 시장에 가지 않았어요.
